# %%
import healpy as hp
import pylab as mplot
# %pylab inline
import astropy.io.fits as pf
from astropy.io import fits
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Read in Redmapper data
hdul = fits.open('./Fits_files/RM_cluster.fits')
data = hdul[1].data
cols = hdul[1].columns
print(cols.names)
# Out:
# ['RA', 'DEC', 'Z', 'LAMBDA', 'JK']

# %%
RM_ran = pf.open('./Fits_files/RM_cluster_rand.fits')[1].data
head = pf.open('./Fits_files/RM_cluster_rand.fits')[1].header
cols_ran = pf.open('./Fits_files/RM_cluster_rand.fits')[1].columns
# Out:
# 2200708
# 4.3466754
# 96.81228
# ColDefs(
#     name = 'RA'; format = 'E'
#     name = 'DEC'; format = 'E'
#     name = 'Z'; format = 'E'
#     name = 'LAMBDA'; format = 'E'
#     name = 'W'; format = 'E'
#     name = 'JK'; format = 'E'
# )

# %%
RM = pf.open('./Fits_files/RM_cluster.fits')[1].data
cols = pf.open('./Fits_files/RM_cluster.fits')[1].columns

#print(np.where(RM['JK'] == -1))
print("Number of RM Clusters after cuts: " + str(len(RM['RA'])))
print(RM[0][0])
print(RM[0][3])
print(cols)
# Out:
# Number of RM Clusters after cuts: 3684
# 306.4992
# 96.81228
# ColDefs(
#     name = 'RA'; format = 'E'
#     name = 'DEC'; format = 'E'
#     name = 'Z'; format = 'E'
#     name = 'LAMBDA'; format = 'E'
#     name = 'JK'; format = 'E'
# )

# %%
# %matplotlib notebook

n0 = np.load('./Sigmag_RM_results/Sigmag_RM_0.npz')
n1 = np.load('./Sigmag_RM_results/Sigmag_RM_1.npz')
n2 = np.load('./Sigmag_RM_results/Sigmag_RM_2.npz')
n3 = np.load('./Sigmag_RM_results/Sigmag_RM_3.npz')
n4 = np.load('./Sigmag_RM_results/Sigmag_RM_4.npz')
n5 = np.load('./Sigmag_RM_results/Sigmag_RM_5.npz')
n6 = np.load('./Sigmag_RM_results/Sigmag_RM_6.npz')

print(n0['w'])
print(n0['xi'])
print(n0['R'])
fig, ax = plt.subplots()
plt.plot(n0['R'],n0['xi'], color = 'red', label = 'mean z = .225')
plt.plot(n1['R'],n1['xi'], color = 'orange', label = 'mean z = .275')
plt.plot(n2['R'],n2['xi'], color = 'yellow', label = 'mean z = .325')
plt.plot(n3['R'],n3['xi'], color = 'green', label = 'mean z = .375')
plt.plot(n4['R'],n4['xi'], color = 'blue', label = 'mean z = .425')
plt.plot(n5['R'],n5['xi'], color = 'purple', label = 'mean z = .475')
plt.plot(n6['R'],n6['xi'], color = 'k', label = 'mean z = .525')
plt.xlabel('log(R)', fontsize = 14)
plt.ylabel('log(xi)', fontsize = 14)
plt.yscale('log')
plt.xscale('log')
plt.legend(fontsize = 11)

#plt.savefig('./Sigmag_RM_results/Sigmag_RM_results.png', dpi = 600)
plt.show()
# Out:
# [4.70809359e+01 7.91977380e+01 1.32657810e+02 2.22258849e+02
#  3.71578461e+02 6.22434288e+02 1.04397288e+03 1.75419202e+03
#  2.95247878e+03 4.97470945e+03 8.39750035e+03 1.41917519e+04
#  2.39259241e+04 4.03510152e+04 6.79717256e+04 1.14410650e+05
#  1.92164826e+05 3.22257196e+05 5.38593508e+05 8.96437546e+05]
# [5.17432884 3.82254046 2.94174344 2.54236341 1.98349471 1.26002991
#  0.900452   0.67980803 0.3706604  0.240228   0.16621742 0.12527784
#  0.11546048 0.0724536  0.07301464 0.04904242 0.04428599 0.03674195
#  0.0320102  0.0208041 ]
# [ 0.16309014  0.21255886  0.27703249  0.36106235  0.47058026  0.61331729
#   0.7993495   1.04180925  1.35781221  1.7696656   2.3064429   3.00603621
#   3.91783108  5.10619278  6.65500991  8.67361631 11.30450906 14.73340768
#  19.20236436 25.02685087]
# <img src="data:image/png;base64,..." width="432">
