# %% [markdown]
# ## Process Run 1

# %%
import numpy as np
x = np.load('./npzs/splashback_cov_WaZP.npz')
y = np.load('./npzs/splashback_cov_RM.npz')

# %%
print(y.files)
R_w = x['r_data']
Sg_w = x['sg_mean']
err_w = x['sg_sig']
cov_w = x['cov']
R_r = y['r_data']
Sg_r = y['sg_mean']
err_r = y['sg_sig']
cov_r = y['cov']
# Out:
# ['cov', 'r_data', 'sg_mean', 'sg_sig']

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

fig, ax = plt.subplots()

plt.plot(R_w,Sg_w, color = 'blue')
plt.plot(R_r,Sg_r, color = 'red')
plt.errorbar(R_w,Sg_w, err_w, fmt = 'b.', label = 'WaZP')
plt.errorbar(R_r,Sg_r, err_r, fmt = 'r.', label = 'Redmapper')
plt.xlabel('log(R)', fontsize = 14, labelpad = -6.)
plt.ylabel('log($\Sigma_g$)', fontsize = 14, labelpad = 0)
plt.yscale('log')
plt.xscale('log')
plt.legend(fontsize = 11)
plt.show()
#plt.savefig('./Mean_Sigmag_compare.png', dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Process Run 2 – Fixing Amplitude Discrepancy

# %%
z = np.load('./npzs/splashback_cov_WaZP_run2.npz')

R_w = z['r_data']
Sg_w = z['sg_mean']
cov_w = z['cov']

fig, ax = plt.subplots()

plt.plot(R_w,Sg_w, color = 'blue')
plt.plot(R_r,Sg_r, color = 'red')
plt.errorbar(R_w,Sg_w, fmt = 'b.', label = 'WaZP')
plt.errorbar(R_r,Sg_r, fmt = 'r.', label = 'Redmapper')
plt.xlabel('log(R)', fontsize = 14, labelpad = -6.)
plt.ylabel('log($\Sigma_g$)', fontsize = 14, labelpad = 0)
plt.yscale('log')
plt.xscale('log')
plt.legend(fontsize = 11)
plt.show()
#plt.savefig('./Mean_Sigmag_compare_run2.png', dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Process Run 3 – With JK Errors

# %% [markdown]
# ## (First Comparison with Chihway's Results as a Sanity Check)

# %%
RM_jk = np.load('./Sigmag_RM_jk_results/splashback_cov_RM_jk.npz')
data = np.load('./chihway_examples/splashback_cov_l20_100_fiducial_bin20.npz')

R_orig = data['r_data']
Sg_orig = data['sg_mean']
err_orig = data['sg_sig']
cov_orig = data['cov']

R_jk = RM_jk['r_data']
Sg_jk = RM_jk['sg_mean']
err_jk = RM_jk['sg_sig']
cov_jk = RM_jk['cov']

fig, ax = plt.subplots()

plt.errorbar(R_jk,Sg_jk, err_jk, fmt = 'r.', capsize = 2.5, label = 'My Jackknife Errors')
plt.errorbar(R_orig, Sg_orig, err_orig, fmt = 'b.', capsize = 2.5, label = "Chihway's Jackknife Errors")
plt.xlabel('log(R)', fontsize = 14, labelpad = -6.)
plt.ylabel('log($\Sigma_g$)', fontsize = 14, labelpad = 0)
plt.yscale('log')
plt.xscale('log')
plt.legend(fontsize = 11)
plt.show()
#plt.savefig('/Users/arielamsellem/Desktop/Mean_Sigmag_compare_jk_errors_RM.png', dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Error bars are very close although mine are systematically larger... (Concerns me a bit...)

# %% [markdown]
# ## WaZP-RM with JK Comparison

# %%
RM_jk = np.load('./Sigmag_RM_jk_results/splashback_cov_RM_jk.npz')
W_jk = np.load('./Sigmag_WaZP_jk_results/splashback_cov_WaZP_jk.npz')

R_w = W_jk['r_data']
Sg_w = W_jk['sg_mean']
err_w = W_jk['sg_sig']
cov_w = W_jk['cov']

R_r = RM_jk['r_data']
Sg_r = RM_jk['sg_mean']
err_r = RM_jk['sg_sig']
cov_r = RM_jk['cov']

fig, ax = plt.subplots()

plt.plot(R_w,Sg_w, color = 'blue')
plt.plot(R_r,Sg_r, color = 'red')
plt.errorbar(R_r,Sg_r, err_r, fmt = 'r.', capsize = 2.5, label = 'Redmapper')
plt.errorbar(R_w, Sg_w, err_w, fmt = 'b.', capsize = 2.5, label = 'WaZP')
plt.xlabel('log(R)', fontsize = 14, labelpad = -6.)
plt.ylabel('log($\Sigma_g$)', fontsize = 14, labelpad = 0)
plt.yscale('log')
plt.xscale('log')
plt.legend(fontsize = 11)
plt.show()
#plt.savefig('/Users/arielamsellem/Desktop/Mean_Sigmag_compare_jk_errors.png', dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(err_r)
print(err_w)
print("Just wanted to make sure the jackknife errors on RM and WaZP are different (meaning I didn't use the same data twice by accident). They are.")
# Out:
# [0.75913915 0.6080623  0.45341655 0.30927251 0.28753661 0.18654409
#  0.12919235 0.10245078 0.07442771 0.0572765  0.04697263 0.04146947
#  0.03911017 0.03586756 0.03293852 0.02887773 0.02767266 0.02440168
#  0.02257387 0.01981155]
# [0.68153806 0.5706875  0.350487   0.29017416 0.19653819 0.14507097
#  0.11764637 0.08275842 0.0653628  0.05527446 0.03881759 0.03200572
#  0.02982685 0.02725801 0.02488003 0.02259038 0.01975691 0.01989581
#  0.01524358 0.01399196]
# Just wanted to make sure the jackknife errors on RM and WaZP are different (meaning I didn't use the same data twice by accident). They are.

# %% [markdown]
# ## Process Run 4 – Only With Matched Clusters in RM and WaZP

# %%
RM_m = np.load('./Sigmag_Matched_results/RM_photoz/splashback_cov_RM_m.npz')
W_m = np.load('./Sigmag_Matched_results/WaZP_photoz/splashback_cov_WaZP_m.npz')

R_m_r = RM_m['r_data']
Sg_m_r = RM_m['sg_mean']
err_m_r = RM_m['sg_sig']
cov_m_r = RM_m['cov']

R_m_w = W_m['r_data']
Sg_m_w = W_m['sg_mean']
err_m_w = W_m['sg_sig']
cov_m_w = W_m['cov']

fig, ax = plt.subplots()

plt.plot(R_m_w,Sg_m_w, color = 'blue')
plt.plot(R_m_r,Sg_m_r, color = 'red')
plt.errorbar(R_m_r,Sg_m_r, err_m_r, fmt = 'r.', capsize = 2.5, label = 'Redmapper Photo-z', zorder = 1)
plt.errorbar(R_m_w, Sg_m_w, err_m_w, fmt = 'b.', capsize = 2.5, label = 'WaZP Photo-z', zorder = 0)
plt.xlabel('log(R)', fontsize = 14, labelpad = -6.)
plt.ylabel('log($\Sigma_g$)', fontsize = 14, labelpad = 0)
plt.yscale('log')
plt.xscale('log')
plt.legend(fontsize = 11)
plt.savefig('/Users/arielamsellem/Desktop/Matched_Sigmag_compare.png', dpi = 600)
plt.show()
